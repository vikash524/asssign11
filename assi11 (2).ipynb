# %%
# Q1
# Explain why we have to use the Exception class while creating a Custom Exception.
# Note: Here Exception class refers to the base class for all the exceptions.

# We use the Exception class as the base class while creating a Custom Exception because it provides the necessary functionality for exception handling.
# By inheriting from the Exception class, our custom exception inherits all the common attributes and methods of the Exception class, making it easier to work with and catch in our code.

# Example:
class CustomError(Exception):
    pass

try:
    raise CustomError("This is a custom exception")
except CustomError as e:
    print("Custom Error occurred:", e)

# Q2
# Write a python program to print Python Exception Hierarchy.

import builtins
print("Python Exception Hierarchy:")
for exc in dir(builtins):
    if isinstance(getattr(builtins, exc), type) and issubclass(getattr(builtins, exc), BaseException):
        print(f"- {exc}")

# Q3
# What errors are defined in the ArithmeticError class? Explain any two with an example.

# ArithmeticError is the base class for arithmetic errors that occur during the execution of arithmetic operations.

# Example 1: ZeroDivisionError
try:
    result = 10 / 0
except ZeroDivisionError as e:
    print("Error:", e)

# Example 2: OverflowError
try:
    result = 10 ** 1000000
except OverflowError as e:
    print("Error:", e)

# Q4
# Why LookupError class is used? Explain with an example KeyError and IndexError.

# LookupError is the base class for errors that occur when a key or index is not found in a mapping or sequence.

# Example 1: KeyError
my_dict = {'a': 1, 'b': 2}
try:
    value = my_dict['c']
except KeyError as e:
    print("Error:", e)

# Example 2: IndexError
my_list = [1, 2, 3]
try:
    value = my_list[3]
except IndexError as e:
    print("Error:", e)

# Q5
# Explain ImportError. What is ModuleNotFoundError?

# ImportError is raised when an import statement fails to find the module being imported.
# ModuleNotFoundError is a subclass of ImportError and is raised specifically when the module being imported cannot be found.

# Q6
# List down some best practices for exception handling in python.

# 1. Be specific in catching exceptions rather than using a generic 'except'.
# 2. Use 'try', 'except', 'else', and 'finally' blocks appropriately.
# 3. Keep the try block as small as possible to isolate the code that might raise an exception.
# 4. Handle exceptions gracefully and provide informative error messages.
# 5. Avoid catching Exception or BaseException directly unless necessary.
# 6. Document the expected exceptions that a function might raise.
# 7. Use custom exceptions for specific error conditions in your application.
# Out:
# Custom Error occurred: This is a custom exception
# Python Exception Hierarchy:
# - ArithmeticError
# - AssertionError
# - AttributeError
# - BaseException
# - BlockingIOError
# - BrokenPipeError
# - BufferError
# - BytesWarning
# - ChildProcessError
# - ConnectionAbortedError
# - ConnectionError
# - ConnectionRefusedError
# - ConnectionResetError
# - DeprecationWarning
# - EOFError
# - EncodingWarning
# - EnvironmentError
# - Exception
# - FileExistsError
# - FileNotFoundError
# - FloatingPointError
# - FutureWarning
# - GeneratorExit
# - IOError
# - ImportError
# - ImportWarning
# - IndentationError
# - IndexError
# - InterruptedError
# - IsADirectoryError
# - KeyError
# - KeyboardInterrupt
# - LookupError
# - MemoryError
# - ModuleNotFoundError
# - NameError
# - NotADirectoryError
# - NotImplementedError
# - OSError
# - OverflowError
# - PendingDeprecationWarning
# - PermissionError
# - ProcessLookupError
# - RecursionError
# - ReferenceError
# - ResourceWarning
# - RuntimeError
# ...
